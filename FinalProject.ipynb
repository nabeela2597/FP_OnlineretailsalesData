# %%
import pandas as pd

#loading the retail dataset

df = pd.read_csv('Online-Retail.csv', encoding='unicode_escape')
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#              InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#         InvoiceDate  Price  Customer ID         Country
# 0  01-12-2009 07:45   6.95      13085.0  United Kingdom
# 1  01-12-2009 07:45   6.75      13085.0  United Kingdom
# 2  01-12-2009 07:45   6.75      13085.0  United Kingdom
# 3  01-12-2009 07:45   2.10      13085.0  United Kingdom
# 4  01-12-2009 07:45   1.25      13085.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.1+ MB

# %%
dfc= df.dropna(subset=['Customer ID'])
dfc
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#              InvoiceDate  Price  Customer ID         Country
# ...

# %%
dfc['Description'].fillna('Unknown', inplace=True)
dfc
# Out:
# C:\Users\Nabeela\AppData\Local\Temp\ipykernel_17792\3023224849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['Description'].fillna('Unknown', inplace=True)
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# ...

# %%
#normalize the price column

dfc['Price']= (dfc['Price']- dfc['Price'].mean())/dfc['Price'].std()
dfc
# Out:
# C:\Users\Nabeela\AppData\Local\Temp\ipykernel_17792\1458956640.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['Price']= (dfc['Price']- dfc['Price'].mean())/dfc['Price'].std()
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# ...

# %%
dfc = dfc[dfc['Quantity'] > 0]
dfc
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#              InvoiceDate     Price  Customer ID         Country
# ...

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407695 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      407695 non-null  object
#  1   StockCode    407695 non-null  object
#  2   Description  407695 non-null  object
#  3   Quantity     407695 non-null  int64
#  4   InvoiceDate  407695 non-null  object
#  5   Price        407695 non-null  float64
#  6   Customer ID  407695 non-null  float64
#  7   Country      407695 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.0+ MB

# %%
dfc.describe()
# Out:
#             Quantity          Price    Customer ID
# count  407695.000000  407695.000000  407695.000000
# mean       13.586686      -0.008342   15368.504107
# std        96.842229       0.488623    1679.795700
# min         1.000000      -0.054653   12346.000000
# 25%         2.000000      -0.037080   13997.000000
# 50%         5.000000      -0.027239   15321.000000
# 75%        12.000000      -0.001934   16812.000000
# max     19152.000000     153.934147   18287.000000

# %%
country_sales= dfc.groupby('Country')['Quantity'].sum().reset_index()

# %%
country_sales
# Out:
#                  Country  Quantity
# 0              Australia     20189
# 1                Austria      6697
# 2                Bahrain       495
# 3                Belgium     12075
# 4                 Brazil       189
# 5                 Canada       894
# 6        Channel Islands     11991
# 7                 Cyprus      4625
# 8                Denmark    229690
# 9                   EIRE    181428
# 10               Finland      3671
# 11                France    162202
# 12               Germany    108740
# 13                Greece      6167
# 14               Iceland       828
# 15                Israel      1132
# 16                 Italy      7389
# 17                 Japan      7311
# 18                 Korea       700
# 19             Lithuania      2306
# 20                 Malta      1549
# 21           Netherlands    183680
# 22               Nigeria       103
# 23                Norway      7867
# 24                Poland      2144
# 25              Portugal     11989
# ...

# %%
dfc['TotalSales']= dfc['Quantity']* dfc['Price']
# Out:
# C:\Users\Nabeela\AppData\Local\Temp\ipykernel_17792\1602309731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['TotalSales']= dfc['Quantity']* dfc['Price']

# %%
country_revenue = dfc.groupby('Country')['TotalSales'].sum().reset_index()

# %%
country_revenue
# Out:
#                  Country     TotalSales
# 0              Australia    -661.292109
# 1                Austria    -177.425230
# 2                Bahrain     -15.722448
# 3                Belgium    -314.698303
# 4                 Brazil      -6.557918
# 5                 Canada     -31.755242
# 6        Channel Islands    -310.258741
# 7                 Cyprus     -92.647133
# 8                Denmark  -11837.518064
# 9                   EIRE   -4909.544934
# 10               Finland     -96.886724
# 11                France   -6809.227056
# 12               Germany   -3097.582248
# 13                Greece    -135.506703
# 14               Iceland     -26.648691
# 15                Israel     -16.888421
# 16                 Italy    -192.008481
# 17                 Japan    -262.890021
# 18                 Korea     -22.532444
# 19             Lithuania     -57.245910
# 20                 Malta      -9.114223
# 21           Netherlands   -6259.911035
# ...

# %%
country_sales.head()
# Out:
#      Country  Quantity
# 0  Australia     20189
# 1    Austria      6697
# 2    Bahrain       495
# 3    Belgium     12075
# 4     Brazil       189

# %%
country_revenue.head()
# Out:
#      Country  TotalSales
# 0  Australia -661.292109
# 1    Austria -177.425230
# 2    Bahrain  -15.722448
# 3    Belgium -314.698303
# 4     Brazil   -6.557918

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
plt.bar(country_revenue['Country'], country_revenue['TotalSales'], color='brown')
plt.title('Total sales revenue by country')
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.xticks(rotation= 90)
plt.show()

# %%
dfc['InvoiceDate']= pd.to_datetime(dfc['InvoiceDate'])
dfc
# Out:
# C:\Users\Nabeela\AppData\Local\Temp\ipykernel_17792\2599753327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfc['InvoiceDate']= pd.to_datetime(dfc['InvoiceDate'])
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# ...

# %%
daily_sales = dfc.groupby(dfc['InvoiceDate'].dt.date)['Quantity'].sum().reset_index()

# %%
daily_sales
# Out:
#     InvoiceDate  Quantity
# 0    2009-01-12     24437
# 1    2009-02-12     29783
# 2    2009-03-12     48033
# 3    2009-04-12     20069
# 4    2009-05-12      5119
# ..          ...       ...
# 302  2010-12-07      8938
# 303  2010-12-08     17769
# 304  2010-12-09      9409
# 305  2010-12-10     28732
# 306  2010-12-11     20051
#
# [307 rows x 2 columns]

# %%
plt.figure(figsize=(15,6))
plt.plot(daily_sales['InvoiceDate'], daily_sales['Quantity'], marker='o', color='orange')
plt.title('Total Quantity sold over time')
plt.xlabel('Date')
plt.ylabel('Total Quantities sold ')
plt.xticks(rotation= 45)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(dfc['Price'], bins=5, color='red', edgecolor='orange')
plt.title('Distribution of Normalized prices')
plt.xlabel('Normalized Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
